# %%
# Import pandas as pd
import pandas as pd
import numpy as np

# 显示所有行
pd.set_option('display.max_rows', None)
# Fix import by including index_col index_col = 0就是不显示
data = pd.read_csv('Data.csv', index_col = 0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 我不是药神 to 禁闭岛
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   导演      100 non-null    object
#  1   演员      100 non-null    object
#  2   评分      100 non-null    float64
#  3   收入      100 non-null    object
#  4   类型      100 non-null    object
#  5   时长      100 non-null    int64
#  6   国家      100 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 6.2+ KB

# %%
data.head()
# Out:
#                导演                        演员   评分      收入        类型   时长    国家
# 电影名称
# 我不是药神         文牧野                徐峥,周一围,王传君  9.6  310002     剧情,喜剧  117  中国大陆
# 肖申克的救赎   弗兰克·德拉邦特       蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿  9.5      暂无     剧情,犯罪  142    美国
# 绿皮书        彼得·法雷里    维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼  9.5   47872  剧情,喜剧,传记  130    美国
# 海上钢琴师    朱塞佩·托纳多雷  蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世  9.3   14376  剧情,爱情,音乐  126   意大利
# 哪吒之魔童降世        饺子               吕艳婷,囧森瑟夫,瀚墨  9.6   66507  动画,喜剧,奇幻  110  中国大陆

# %%
import pandas as pd
from matplotlib import pyplot as plt

#plt.rcParams['font.sans-serif'] = ['SimHei']

datas = pd.read_csv('Data.csv', encoding='utf-8')

long_time = list(datas['时长'])

d = 10
num_bins = int((max(long_time) - min(long_time)) / d)

plt.hist(long_time, range(min(long_time), max(long_time) + d, d), density=True)

plt.xticks(range(min(long_time), max(long_time) + d, d))
plt.grid(alpha=0.4)

plt.title('The Movie Duration Distribution')
plt.xlabel('Duration')
plt.ylabel('Proportion')
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams['font.sans-serif']=['SimHei']
datas = pd.read_csv('Data.csv', encoding='UTF-8')

datas['country'] = datas['国家']
# print(datas['country'])

country = datas.groupby('country')['country'].count()
# print(country)
# print(list(country))
# print(list(country.index))
explods = [0, 0.2, 0, 0, 0, 0, 0, 0, 0]

plt.pie(list(country), labels=list(country.index), autopct='%1.1f%%')
plt.title('电影的国家/地区分布情况')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30005 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24433 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
