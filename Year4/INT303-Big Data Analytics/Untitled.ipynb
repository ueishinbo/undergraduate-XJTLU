# %%
# Import pandas as pd
import pandas as pd
import numpy as np
# 显示所有行
pd.set_option('display.max_rows', None)
# Fix import by including index_col index_col = 0就是不显示
data = pd.read_csv('Data.csv', index_col = 0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 哪吒之魔童降世 to 致命魔术
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   导演      100 non-null    object
#  1   演员      100 non-null    object
#  2   评分      100 non-null    float64
#  3   收入      100 non-null    object
#  4   类型      100 non-null    object
#  5   时长      100 non-null    object
#  6   国家      100 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 6.2+ KB

# %%
data.head()
# Out:
#                导演                        演员   评分      收入        类型     时长  \
# 电影名称
# 哪吒之魔童降世        饺子               吕艳婷,囧森瑟夫,瀚墨  9.6   66507  动画,喜剧,奇幻  110分钟
# 我不是药神         文牧野                徐峥,周一围,王传君  9.6  310002     剧情,喜剧  117分钟
# 肖申克的救赎   弗兰克·德拉邦特       蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿  9.5      暂无     剧情,犯罪  142分钟
# 海上钢琴师    朱塞佩·托纳多雷  蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世  9.3   14376  剧情,爱情,音乐  126分钟
# 绿皮书        彼得·法雷里    维果·莫腾森,马赫沙拉·阿里,琳达·卡德里尼  9.5   47872  剧情,喜剧,传记  130分钟
#
#            国家
# 电影名称
# 哪吒之魔童降世  中国大陆
# 我不是药神    中国大陆
# 肖申克的救赎     美国
# 海上钢琴师     意大利
# 绿皮书        美国

# %%
a = pd.DataFrame(data['评分'],columns=['评分'])
b = pd.DataFrame(a['评分'].value_counts())
# Out:
# Float64Index([8.8, 9.3, 8.9, 8.7, 9.0, 9.1, 8.6, 9.2, 9.4, 9.5, 8.5, 9.6, 8.4,
#               8.1, 9.8, 8.0, 8.2],
#              dtype='float64')

# %%
data.drop_duplicates(subset=['评分'])
# Out:
#                   导演                                演员   评分      收入  \
# 电影名称
# 哪吒之魔童降世           饺子                       吕艳婷,囧森瑟夫,瀚墨  9.6   66507
# 肖申克的救赎      弗兰克·德拉邦特               蒂姆·罗宾斯,摩根·弗里曼,鲍勃·冈顿  9.5      暂无
# 海上钢琴师       朱塞佩·托纳多雷          蒂姆·罗斯,比尔·努恩 ,克兰伦斯·威廉姆斯三世  9.3   14376
# 小偷家族            是枝裕和                     中川雅也,安藤樱,松冈茉优  8.1    9675
# 霸王别姬             陈凯歌                        张国荣,张丰毅,巩俐  9.4       5
# 触不可及        奥利维埃·纳卡什               弗朗索瓦·克鲁塞,奥玛·希,安娜·勒尼  9.1      暂无
# 盗梦空间        克里斯托弗·诺兰         莱昂纳多·迪卡普里奥,渡边谦,约瑟夫·高登-莱维特  9.0   49620
# 怦然心动           罗伯·莱纳            玛德琳·卡罗尔,卡兰·麦克奥利菲,艾丹•奎因  8.9      暂无
# 辛德勒的名单     史蒂文·斯皮尔伯格               连姆·尼森,拉尔夫·费因斯,本·金斯利  9.2      暂无
# 小丑           托德·菲利普斯           华金·菲尼克斯,罗伯特·德尼罗,亚历克·鲍德温  8.6      暂无
# 摔跤吧！爸爸        涅提·蒂瓦里            阿米尔·汗,沙克希·坦沃,法缇玛·萨那·纱卡  9.8  129932
# 熔炉               黄东赫                        孔刘,郑有美,金智英  8.8      暂无
# 被嫌弃的松子的一生       中岛哲也                   中谷美纪,永山瑛太,伊势谷友介  8.5      暂无
# 死亡诗社           彼得·威尔            罗宾·威廉姆斯,伊桑·霍克,柯特伍德·史密斯  8.7      暂无
# 请以你的名字呼唤我    卢卡·瓜达尼诺             提莫西·查拉梅,艾米·汉莫,迈克尔·斯图巴  8.0      暂无
# 西西里的美丽传说    朱塞佩·托纳多雷  莫妮卡·安娜·玛丽亚·贝鲁奇,朱塞佩·苏尔法罗,玛蒂尔德·皮亚纳  8.2      暂无
# 天使爱美丽              让                奥黛丽·塔图,马修·卡索维茨,吕菲斯  8.4      暂无
#
#                     类型     时长    国家
# 电影名称
# 哪吒之魔童降世       动画,喜剧,奇幻  110分钟  中国大陆
# 肖申克的救赎           剧情,犯罪  142分钟    美国
# 海上钢琴师         剧情,爱情,音乐  126分钟   意大利
# 小偷家族             剧情,犯罪  121分钟    日本
# 霸王别姬             剧情,爱情  171分钟  中国香港
# 触不可及             剧情,喜剧  112分钟    法国
# 盗梦空间       动作,悬疑,惊悚,科幻  148分钟    英国
# 怦然心动                爱情   90分钟    美国
# 辛德勒的名单        剧情,历史,战争  195分钟    美国
# 小丑            剧情,惊悚,犯罪  122分钟    美国
# 摔跤吧！爸爸        喜剧,动作,家庭  140分钟    印度
# 熔炉                  剧情  125分钟    韩国
# 被嫌弃的松子的一生        剧情,歌舞  130分钟    日本
# 死亡诗社                剧情  128分钟    美国
# 请以你的名字呼唤我        爱情,剧情  132分钟    德国
# 西西里的美丽传说      剧情,爱情,战争  109分钟   意大利
# 天使爱美丽               爱情  122分钟    德国
